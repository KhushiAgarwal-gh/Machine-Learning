# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('housing.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df['total_rooms'].iloc[::2]=np.nan
# Out:
# C:\Users\Khushi Agarwal\AppData\Local\Temp\ipykernel_5716\2442381296.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['total_rooms'].iloc[::2]=np.nan
# ...

# %%
df['total_rooms']
# Out:
# 0           NaN
# 1        7099.0
# 2           NaN
# 3        1274.0
# 4           NaN
#           ...
# 20635    1665.0
# 20636       NaN
# 20637    2254.0
# 20638       NaN
# 20639    2785.0
# Name: total_rooms, Length: 20640, dtype: float64

# %%
df['total_bedrooms'].iloc[::4]=np.nan
# Out:
# C:\Users\Khushi Agarwal\AppData\Local\Temp\ipykernel_5716\2401764684.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['total_bedrooms'].iloc[::4]=np.nan
# ...

# %%
df['total_bedrooms']
# Out:
# 0           NaN
# 1        1106.0
# 2         190.0
# 3         235.0
# 4           NaN
#           ...
# 20635     374.0
# 20636       NaN
# 20637     485.0
# 20638     409.0
# 20639     616.0
# Name: total_bedrooms, Length: 20640, dtype: float64

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0          NaN             NaN
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0          NaN           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0          NaN             NaN
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0          NaN             NaN
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0          NaN           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
plt.hist(df['total_rooms'])
plt.show()

# %%
sns.kdeplot(df['total_rooms'])
# Out:
# <Axes: xlabel='total_rooms', ylabel='Density'>

# %%
sns.boxplot(df['total_rooms'])
# Out:
# <Axes: ylabel='total_rooms'>

# %%
df.isnull().sum()
# Out:
# longitude                 0
# latitude                  0
# housing_median_age        0
# total_rooms           10320
# total_bedrooms         5319
# population                0
# households                0
# median_income             0
# median_house_value        0
# ocean_proximity           0
# dtype: int64

# %%
df.isna().sum()
# Out:
# longitude                 0
# latitude                  0
# housing_median_age        0
# total_rooms           10320
# total_bedrooms         5319
# population                0
# households                0
# median_income             0
# median_house_value        0
# ocean_proximity           0
# dtype: int64

# %%
df['total_rooms'].fillna(df['total_rooms'].mean())
# Out:
# 0        2665.932946
# 1        7099.000000
# 2        2665.932946
# 3        1274.000000
# 4        2665.932946
#             ...
# 20635    1665.000000
# 20636    2665.932946
# 20637    2254.000000
# 20638    2665.932946
# 20639    2785.000000
# Name: total_rooms, Length: 20640, dtype: float64

# %%
df['total_rooms'].fillna(df['total_rooms'].median(),inplace=True)

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0       2154.5             NaN
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       2154.5           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       2154.5             NaN
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0       2154.5             NaN
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       2154.5           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
np.median(df['total_rooms'])
# Out:
# np.float64(2154.5)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='median')
imputer
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.fit(df[['total_rooms']])
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([2154.5])

# %%
np.median(df['total_rooms'])
# Out:
# np.float64(nan)

# %%
imputer.transform(df['total_rooms'])
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 imputer.transform(df['total_rooms'])
#
# File D:\Anaconda\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...
